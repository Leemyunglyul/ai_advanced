# %% [markdown]
# # [실습] Instruction Tuning
#
# Continuous Pretraining(CPT)을 통해 지식을 주입한 뒤에는
#
# Instruction Tuning을 통해 질의응답 능력을 학습시킵니다.
#
# CPT 과정과 마찬가지로, 학습 중 다양한 데이터를 함께 학습시켜 일반화 성능을 유지할 수 있습니다.

# %%
# !pip install tensorboard transformers==4.56.0 seaborn langchain langchain-huggingface pandas accelerate datasets huggingface_hub trl==0.19.1 bitsandbytes -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 100.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 376.2/376.2 kB 30.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 MB 36.1 MB/s eta 0:00:00

# %% [markdown]
# 허깅페이스 토큰을 입력합니다.

# %%
import os

from huggingface_hub import login

# 허깅페이스 토큰 로그인: 이번 실습에서는 필요하지 않습니다.
# login(token='')

# %% [markdown]
# 모델의 주소를 입력합니다.
# 이전 학습에서 그대로 이어서 진행하는 경우, 로컬 주소를 넣어도 됩니다.

# %%
import torch
from transformers import AutoModelForCausalLM,AutoTokenizer

model_id="NotoriousH2/gemma-3-1b-pt-MED_CPT"
# 모델의 주소
# (로컬 주소도 가능)

model_name = model_id.split('/')[1]
print("## MODEL:", model_name)
# Out:
# ## MODEL: gemma-3-1b-pt-MED_CPT

# %% [markdown]
# 모델과 토크나이저를 불러옵니다.

# %%
tokenizer = AutoTokenizer.from_pretrained(
    model_id,
)
model = AutoModelForCausalLM.from_pretrained(model_id,
                                             torch_dtype='auto',
                                             device_map="auto",
                                             attn_implementation="eager",
                                            )
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# `torch_dtype` is deprecated! Use `dtype` instead!
# The following generation flags are not valid and may be ignored: ['cache_implementation']. Set `TRANSFORMERS_VERBOSITY=info` for more details.

# %% [markdown]
# Chat Template 확인을 위해 tokenizer의 템플릿을 확인합니다.

# %%
print(tokenizer.chat_template)
# Out:
# None

# %% [markdown]
# Pretrain 모델에 해당 템플릿이 포함된 경우도 있지만, 이번 경우에는 설정이 되어 있지 않은 상황입니다.

# %% [markdown]
# Instruct 모델의 토크나이저를 추가로 불러와 활용하겠습니다.

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

instruct_model_id = 'unsloth/gemma-3-1b-it'


tokenizer = AutoTokenizer.from_pretrained(
    instruct_model_id,
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.69M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/670 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]

# %%
print(tokenizer.chat_template[:100])
# Out:
# {{ bos_token }}
# {%- if messages[0]['role'] == 'system' -%}
#     {%- if messages[0]['content'] is stri

# %%
tokenizer.eos_token
# Out:
# '<end_of_turn>'

# %% [markdown]
# 학습 데이터를 불러옵니다.

# %% [markdown]
# ## [중요]
# 이번에는 모델의 일반화 성능을 평가하기 위해, 모델을 Train/Test로 분리합니다.
#
# Test 데이터는 검증 데이터에 해당하며, 학습에는 참여하지 않으나
# 학습의 과적합과 종료 여부를 판단하는 과정에 활용합니다.

# %%
from datasets import load_dataset

file_path = ['medical_qa_data.json']

# 1. load_dataset으로 DatasetDict 형태로 불러오기
medQA_data = load_dataset("json", data_files={"train": file_path})

# 2. 데이터 분할 (9:1)

medQA_data = medQA_data["train"].train_test_split(test_size=0.1, seed=42)

medQA_data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'disease', 'question_type', 'patient_type', 'age_group', 'pair_number', 'question', 'answer', 'timestamp'],
#         num_rows: 1292
#     })
#     test: Dataset({
#         features: ['id', 'disease', 'question_type', 'patient_type', 'age_group', 'pair_number', 'question', 'answer', 'timestamp'],
#         num_rows: 144
#     })
# })

# %%
# 학습에 사용할 train
print('Question:', medQA_data['train'][0]['question'])
print('Answer:', medQA_data['train'][0]['answer'])
# Out:
# Question: 12살 아들이 한 달 전부터 가끔씩 왼쪽 가슴이 쿡쿡 쑤신다고 합니다. 혹시 심근경색일 가능성이 있나요? 병원에서는 어떤 검사를 받게 되나요?
# Answer: 소아의 심근경색은 매우 드물지만, 증상이 반복된다면 심장 관련 검사가 필요합니다. 병원에서는 심전도, 흉부 X선, 혈액검사 등을 통해 심장 상태를 확인하게 됩니다. 소아과 전문의 상담을 권합니다.

# %%
# 검증에 사용할 test
print('Question:', medQA_data['test'][0]['question'])
print('Answer:', medQA_data['test'][0]['answer'])
# Out:
# Question: 73세 어머님이 최근 건강검진에서 폐에 결절이 발견되어 추가로 CT 검사를 받았습니다. 검사 결과가 암일 가능성이 있다고 하는데, 어떤 추가 검사가 필요한지 궁금합니다.
# Answer: 폐 결절이 암일 가능성이 있다면 조직검사(생검)가 필요할 수 있습니다. PET-CT나 기관지내시경 등 추가 검사를 통해 정확한 진단과 병기 확인이 중요합니다. 전문의와 상의해 신속히 진행하시길 권합니다.

# %% [markdown]
# QA 데이터만으로 학습해도 되지만, 일반 QA를 포함하여 학습시키면 기존 능력을 다소 유지시킬 수 있습니다.
#
# 대표적인 한국어 Instruction Data인 KoAlpaca-RealQA 데이터를 합쳐 보겠습니다.
#
# https://huggingface.co/datasets/beomi/KoAlpaca-RealQA (인증 필요)

# %%
# 인증이 필요하므로 별도의 인증 후 토큰 입력
login(token='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')

realQA_data = load_dataset("beomi/KoAlpaca-RealQA")
realQA_data = realQA_data["train"].train_test_split(test_size=0.1, seed=42)

realQA_data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['custom_id', 'question', 'answer'],
#         num_rows: 16671
#     })
#     test: Dataset({
#         features: ['custom_id', 'question', 'answer'],
#         num_rows: 1853
#     })
# })

# %%
print('Question:', realQA_data['train'][0]['question'])
print('Answer:', realQA_data['train'][0]['answer'])
# Out:
# Question: 절약하는 방법
# Answer: 절약하는 방법에는 여러 가지가 있습니다. 아래에 몇 가지 일반적인 절약 팁을 소개합니다:
#
# 1. **예산 계획 수립**: 수입과 지출을 명확히 파악하고 예산을 세워 지출을 관리합니다. 매월 고정 비용과 변동 비용을 나누어 계획하세요.
#
# 2. **필요와 욕구 구분**: 구매 전에 해당 물품이 정말 필요한 것인지 아니면 단순한 욕구인지 평가하세요. 필요에 따라 우선순위를 정합니다.
#
# 3. **저축 습관**: 수입의 일정 부분을 저축으로 자동이체 설정하여 저축을 습관화하세요. 비상금을 마련하고 장기적인 목표를 위해 저축 계획을 세웁니다.
#
# 4. **외식 줄이기**: 가능한 집에서 요리해 먹고 외식을 줄입니다. 계획적인 식단을 세우면 식비를 절감할 수 있습니다.
#
# 5. **공과금 절약**: 전기, 가스, 수도 사용량을 줄이고, 효율적인 에너지 사용을 통해 공과금을 절약하세요. 에너지 절약형 가전제품 사용도 도움이 됩니다.
#
# 6. **중고 활용**: 필요한 물품을 중고로 구매하거나, 필요 없는 물품을 중고로 판매해 수익을 창출합니다.
#
# 7. **할인 및 쿠폰 활용**: 할인 행사나 쿠폰 등을 적극 활용하여 필요한 물품을 저렴하게 구매하세요.
#
# 8. **구독 서비스 검토**: 정기적으로 사용하지 않는 구독 서비스를 취소하거나 필요성을 재검토합니다.
#
# 9. **신용카드 사용 관리**: 신용카드를 사용할 경우 적절한 한도를 설정하고, 계획된 범위 내에서만 사용하여 미납 금액이 발생하지 않도록 합니다.
#
# 10. **교통비 절약**: 대중교통을 이용하거나, 걷기나 자전거 타기를 통해 교통비를 절약합니다. 카풀을 통해 비용을 나누는 것도 좋은 방법입니다.
#
# 11. **취미 생활 비용 절감**: 무료 또는 저렴한 취미 활동을 찾아 즐기고, 유료 취미와 무료 취미를 적절히 조합합니다.
#
# 이러한 방법들을 생활에 적용하면 점진적으로 지출을 줄이고 더 많은 금액을 절약할 수 있을 것입니다.

# %%
# 학습에 참여하지 않는 validation
print('Question:', realQA_data['test'][0]['question'])
print('Answer:', realQA_data['test'][0]['answer'])
# Out:
# Question: 항공우주공학 연구가 우주 환경을 어떻게 보호하려고 노력하고 있는가?
# Answer: 항공우주공학 연구는 다양한 방법을 통해 우주 환경 보호에 기여하고 있습니다. 주요 방법은 다음과 같습니다.
#
# 1. **우주 쓰레기 감소**: 우주에 버려지는 인공 위성과 로켓 잔해는 시간이 지남에 따라 우주 쓰레기가 되어 다른 인공물과 충돌할 위험을 증가시킵니다. 연구자들은 우주 쓰레기 추적 기술을 개선하고, 수명을 다한 위성을 안전하게 처리하는 방법을 개발하여 이러한 문제를 줄이기 위해 노력하고 있습니다.
#
# 2. **지속 가능한 연료**: 전통적인 로켓 추진 연료는 환경에 해로울 수 있기 때문에, 연구자들은 더 친환경적인 연료 옵션을 탐색하고 있습니다. 전기 추진, 이온 추진 및 수소 연료와 같은 대안이 이를 위한 연구 주제입니다.
#
# 3. **위성 수명 연장**: 위성의 수명을 늘리기 위해 연구자들은 모듈형 설계 및 우주에서의 정비 기술을 발전시키고 있습니다. 이는 새로운 위성을 발사하는 필요성을 줄여주어 우주 환경에 긍정적인 영향을 미칩니다.
#
# 4. **우주 환경 영향 평가**: 새로운 우주 임무나 기술이 우주 환경에 미칠 영향을 사전에 평가하고, 이를 완화할 수 있는 전략을 개발하는 것이 중요합니다. 환경 감시와 영향 평가를 위한 연구도 활발히 진행되고 있습니다.
#
# 5. **폐기물 관리 기술**: 우주 탐사 중 발생하는 폐기물을 안전하게 처리하기 위한 기술이 개발되고 있습니다. 자원을 재활용하거나 우주에서 발생하는 오염을 줄이기 위한 시스템을 구축하는 것이 목표입니다.
#
# 이러한 노력들은 인류의 우주 탐사가 지속 가능하고 책임감 있게 이루어질 수 있도록 돕고자 하는 연구자들의 의지를 반영합니다.

# %% [markdown]
# 두 데이터를 결합하여 전체 데이터를 구성합니다.
# 비율은 학습의 결과를 보면서 결정해야 합니다.

# %%
[realQA_data, medQA_data]
# Out:
# [DatasetDict({
#      train: Dataset({
#          features: ['custom_id', 'question', 'answer'],
#          num_rows: 16671
#      })
#      test: Dataset({
#          features: ['custom_id', 'question', 'answer'],
#          num_rows: 1853
#      })
#  }),
#  DatasetDict({
#      train: Dataset({
#          features: ['id', 'disease', 'question_type', 'patient_type', 'age_group', 'pair_number', 'question', 'answer', 'timestamp'],
#          num_rows: 1292
#      })
#      test: Dataset({
#          features: ['id', 'disease', 'question_type', 'patient_type', 'age_group', 'pair_number', 'question', 'answer', 'timestamp'],
#          num_rows: 144
#      })
#  })]

# %%
from datasets import concatenate_datasets, DatasetDict

# 이제 Dataset들끼리 합침
merged_train = concatenate_datasets([realQA_data['train'], medQA_data['train']])
merged_test = concatenate_datasets([realQA_data['test'], medQA_data['test']])

# DatasetDict로 재구성
data = DatasetDict({
    'train': merged_train.shuffle(seed=42),
    'test': merged_test.shuffle(seed=42)
})
data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['custom_id', 'question', 'answer', 'id', 'disease', 'question_type', 'patient_type', 'age_group', 'pair_number', 'timestamp'],
#         num_rows: 17963
#     })
#     test: Dataset({
#         features: ['custom_id', 'question', 'answer', 'id', 'disease', 'question_type', 'patient_type', 'age_group', 'pair_number', 'timestamp'],
#         num_rows: 1997
#     })
# })

# %% [markdown]
# 이제 학습 데이터가 준비되었습니다!

# %% [markdown]
# 학습 데이터는 토크나이저의 Chat 템플릿으로 변환해야 합니다.

# %% [markdown]
# 토크나이저로부터, 템플릿을 변환하는 함수를 생성합니다.

# %%
def convert_format(question,answer=None):
    # question, answer 세트(학습시) 또는 question만 입력(실행시)

    chat = [{'role': 'user', 'content': f"{question}"}]

    if answer:
        chat.append({'role':'assistant', 'content':f"{answer}"})

        return {'text':tokenizer.apply_chat_template(chat, tokenize=False)}
        # 학습해야 하는 데이터이므로 Generation Prompt 넣지 않음

    return {'text': tokenizer.apply_chat_template(chat, tokenize=False, add_generation_prompt=True)}
    # 입력으로 전달해야 하는 데이터이므로 add_generation_prompt 넣음

# %%
print(convert_format('안녕?', answer='그래 안녕')['text'])
# Out:
# <bos><start_of_turn>user
# 안녕?<end_of_turn>
# <start_of_turn>model
# 그래 안녕<end_of_turn>

# %% [markdown]
# `map`으로 QA 데이터세트를 전처리합니다.

# %%
data = data.map(lambda x:convert_format(x['question'], x['answer']))

# %% [markdown]
# 예시 데이터는 아래와 같습니다.

# %%
print(data['test'][10]['text'])
# Out:
# <bos><start_of_turn>user
# 당신은 중고거래 판매자입니다. 판매자는 상품 가격과 구매자와 판매자가 제시한 가격을 참고해서 적절한 근거와 함께 합의 가격을 제시합니다.
# 제목: 삼성 스탠딩 에어컨 + 실외기
# 상품 설명: 제조년월일 2012.04 에너지효율 1등급 청소등 관리 잘했고 작동도 아무 문제없이 잘됩니다. 실외기 포함입니다. 필요하시면 거치대도 드립니다.리모컨은 없습니다. 7.25 오전에 분리해서 1층에 내려드릴 수 있습니다. 예약금 2만원 입니다. 일원역 근처입니다.
# 상품 가격: 150000원
#
# 구매자: 안녕하세요! 네고 가능할까요?<end_of_turn>
# <start_of_turn>model
# 안녕하세요! 삼성 스탠딩 에어컨 + 실외기는 에너지효율 1등급인 제품으로, 청소 및 관리가 잘 되어 있고 문제 없이 작동하는 상태입니다. 실외기와 거치대도 포함되어 있으며, 편리한 1층 수령이 가능하다는 점에서 150,000원의 가격은 매우 경쟁력 있는 가격이라고 생각됩니다.
#
# 하지만 구매자님의 관심을 고려하여 약간의 할인을 제안드릴 수 있습니다. 리모컨이 없는 점을 감안하여 140,000원으로 제시드리고자 합니다. 이 가격은 품질과 추가 제공품을 고려했을 때 매우 합리적이라고 판단됩니다. 어떻게 생각하시나요?<end_of_turn>

# %% [markdown]
# 이전 실습과 동일하게, 토큰 수를 세어 보겠습니다.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from collections import Counter

def analyze_token_distribution(dataset, text_column='text', bins=30):

    # 토큰 수 계산
    token_counts = []
    for text in dataset[text_column]:
        tokens = tokenizer.encode(text)
        token_counts.append(len(tokens))

    # 기본 통계 계산
    stats = {
        '평균 토큰 수': np.mean(token_counts),
        '중앙값': np.median(token_counts),
        '최소 토큰 수': min(token_counts),
        '최대 토큰 수': max(token_counts),
        '표준편차': np.std(token_counts),
        '90퍼센타일': np.percentile(token_counts, 90),
        '95퍼센타일': np.percentile(token_counts, 95),
        '99퍼센타일': np.percentile(token_counts, 99),
        '총 샘플 수': len(token_counts)
    }

    # 분포 시각화
    plt.figure(figsize=(12, 6))

    # 히스토그램과 KDE
    sns.histplot(data=token_counts, bins=bins, kde=True)
    plt.title(f'Token Length Distribution for {text_column}')
    plt.xlabel('Token Count')
    plt.ylabel('Frequency')

    plt.tight_layout()
    plt.show()

    # 상세 통계 출력
    print("\n=== 토큰 수 통계 ===")
    for key, value in stats.items():
        print(f"{key}: {value:.1f}")

    return stats

print(analyze_token_distribution(data['train']))
# Out:
# === 토큰 수 통계 ===
# 평균 토큰 수: 320.8
# 중앙값: 337.0
# 최소 토큰 수: 20.0
# 최대 토큰 수: 2606.0
# 표준편차: 180.6
# 90퍼센타일: 530.0
# 95퍼센타일: 591.0
# 99퍼센타일: 778.0
# 총 샘플 수: 17963.0
# {'평균 토큰 수': np.float64(320.83410343483825), '중앙값': np.float64(337.0), '최소 토큰 수': 20, '최대 토큰 수': 2606, '표준편차': np.float64(180.62117631070265), '90퍼센타일': np.float64(530.0), '95퍼센타일': np.float64(591.0), '99퍼센타일': np.float64(778.0), '총 샘플 수': 17963}

# %% [markdown]
# Instruction Tuning을 수행합니다.
# 이번에는 길이가 짧으므로, 전처리를 추가로 하지 않습니다.

# %%
from trl import SFTTrainer, SFTConfig
from trl import DataCollatorForCompletionOnlyLM
from accelerate import Accelerator

# GPU를 적게 쓰는 Gradient Checkpointing
model.gradient_checkpointing_enable()
# Checkpointing을 수행하는 경우 use_cache = False
model.config.use_cache = False

tokenizer.pad_token = tokenizer.eos_token


sft_config = SFTConfig(
    report_to='none',

    ######## 추가된 부분 ##############
    eval_strategy="steps",
    eval_steps=100,
    ## 100 step마다 검증 데이터를 통한 로스 계산
    save_total_limit=3,          # 최대 3개 체크포인트만 유지
    load_best_model_at_end=True, # 학습 끝나면 최고 모델 로드
    metric_for_best_model="eval_loss",  # 최고 모델 기준은 Evaluation Loss 기준
    #################################

    # Callback을 통해 중간 과정을 체크할 수도 있음
    # 테스트 문제 넣고 출력 확인하거나, 다른 LLM으로 평가하거나, ...

    num_train_epochs=3,

    dataset_text_field="text",
    # dataset 'text' 필드를 사용

    per_device_train_batch_size=4, # T4= 2
    gradient_accumulation_steps=4,

    max_seq_length=800,
    lr_scheduler_type='cosine',

    learning_rate=2e-5,
    # Instruction Tuning은 더 낮은 LR
    warmup_ratio=0.03,

    bf16=True,

    optim="paged_adamw_8bit",

    output_dir="outputs",
    logging_steps=100,


    save_steps=100
    # 추가: 100 step마다 체크포인트 저장

)

# %% [markdown]
# Data Collator는 Trainer에 넣을 데이터를 전달합니다.
# Instruction Tuning의 경우, 출력 부분부터 학습시켜도 됩니다.
#
# collator를 전달하지 않는 경우, CPT처럼 전체 토큰을 예측합니다.

# %%
response_template = "<start_of_turn>model"
# 답변 부분만 학습시키기

collator = DataCollatorForCompletionOnlyLM(response_template, tokenizer=tokenizer)
# Data Collator : 데이터를 어떻게 전달할 것인가?
# Next Token Prediction의 방법은 동일하나, 어디서부터 학습시킬 것인지를 결정
# 질문 내용까지 학습하기 VS 답변만 학습하기
# DataCollator를 전달하지 않으면, 전체 텍스트를 그대로 학습

# %% [markdown]
# 학습을 수행합니다.
# Instruction Data는 데이터가 더 짧으므로, Batch를 늘려도 될 것 같습니다.

# %%
accelerator = Accelerator()

trainer = SFTTrainer(
    model=model,
    train_dataset=data['train'],

    ## 추가된 부분
    eval_dataset=data['test'],
    ## 검증데이터 활용

    args=sft_config,
    data_collator=collator
)

with accelerator.main_process_first():
    trainer.train()

# Loss Function : Cross Entropy
# 입력 데이터(배치)에 대한 평균 예측 확률 : e^(-Loss)
# Ex) 0.2 --> 81% (e^-0.2)
# Out:
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'pad_token_id': 1}.
#     <div>
#
#       <progress value='236' max='3369' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 236/3369 15:56 < 3:33:27, 0.24 it/s, Epoch 0.21/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>1.551100</td>
#       <td>1.392007</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.365200</td>
#       <td>1.335579</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='3369' max='3369' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3369/3369 5:16:48, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>1.551100</td>
#       <td>1.392007</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.365200</td>
#       <td>1.335579</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.320100</td>
#       <td>1.312961</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.310200</td>
#       <td>1.293573</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.289500</td>
#       <td>1.280948</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.262700</td>
#       <td>1.268612</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>1.273200</td>
#       <td>1.259215</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>1.253500</td>
#       <td>1.251668</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>1.251100</td>
#       <td>1.241872</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.247300</td>
#       <td>1.235059</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>1.236400</td>
#       <td>1.227526</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>1.109600</td>
#       <td>1.234878</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>1.066500</td>
#       <td>1.234907</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>1.055900</td>
#       <td>1.228535</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>1.069100</td>
#       <td>1.228614</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>1.054300</td>
#       <td>1.222985</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>1.046000</td>
#       <td>1.219384</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>1.050100</td>
#       <td>1.219400</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>1.055800</td>
#       <td>1.214860</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>1.052900</td>
#       <td>1.213346</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>1.049200</td>
#       <td>1.211959</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>1.042300</td>
#       <td>1.210304</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>1.001600</td>
#       <td>1.224884</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.965200</td>
#       <td>1.226823</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.963500</td>
#       <td>1.228545</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.964300</td>
#       <td>1.228830</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.952400</td>
#       <td>1.228673</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.964800</td>
#       <td>1.228662</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>0.960600</td>
#       <td>1.228891</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.956100</td>
#       <td>1.228772</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>0.971500</td>
#       <td>1.228683</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.953400</td>
#       <td>1.228665</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.949700</td>
#       <td>1.228778</td>
#     </tr>
#   </tbody>
# </table><p>
# There were missing keys in the checkpoint model loaded: ['lm_head.weight'].

# %% [markdown]
# Training Loss과 Validation Loss는 처음에는 함께 감소하나
# 과적합이 발생하면 Validation Loss가 점점 증가하게 됩니다.
# `metric_for_best_model="eval_loss"을 통해 체크포인트 중 가장 val loss가 낮은 가중치를 로드합니다.

# %%
model.eval()
torch.cuda.empty_cache()

# %% [markdown]
# 만든 모델을 평가합니다.

# %%
from transformers import pipeline

# 파인 튜닝 모델이므로, 공식 파리미터를 따를 필요는 없음

gen_config = dict(
    do_sample=True,
    max_new_tokens=1024,
    repetition_penalty = 1.1,
    temperature = 0.1,
    top_p = 0.95,
    top_k = 64,

)

pipe = pipeline("text-generation", model=model, tokenizer=tokenizer, return_full_text=False,
                **gen_config)
# Out:
# Device set to use cuda:0

# %% [markdown]
# 만들어진 모델은, 랭체인을 이용해 실행해 봅시다.

# %%
from langchain_huggingface import HuggingFacePipeline, ChatHuggingFace

base_llm = HuggingFacePipeline(pipeline=pipe, pipeline_kwargs=gen_config)

llm = ChatHuggingFace(llm=base_llm, tokenizer=tokenizer)

# %%
from langchain.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

prompt = ChatPromptTemplate([('user', '{question}\n')])

chain = prompt | llm | StrOutputParser()

# %%
inputs = [
    "제 1형 당뇨병은 어떻게 치료하나요?",
    "고혈압인데 먹으면 안되는 거 있나요?",
    "충치가 너무 아파요.",
    "불안장애 환자의 식이는 어떻게 해야 되나요?"
]
for i in inputs:
    prompt = convert_format(i)['text']
    print(prompt)
    for s in base_llm.stream(prompt):
        print(s,end='')
    print('\n--------------------\n')
# Out:
# <bos><start_of_turn>user
# 제 1형 당뇨병은 어떻게 치료하나요?<end_of_turn>
# <start_of_turn>model
#
# 제 1형 당뇨병의 치료는 주로 인슐린 주사와 식이조절을 통해 이루어집니다. 이 질환은 신체의 내분비계가 제대로 작동하지 않아 혈당이 매우 높아지는 상태입니다.
#
# 1. **인슐린 주사**: 제1형 당뇨병 환자들은 대부분 인슐린 주사를 사용하여 혈당을 조절합니다. 인슐린은 소장에서 흡수되어 혈액으로 들어가고, 이후 세포로 이동하여 포도당을 에너지원으로 사용하게 됩니다.
#
# 2. **식이요법**: 제1형 당뇨병 환자는 저탄수화물 식단과 높은 섬유질 함량을 가진 음식을 섭취하는 것이 중요합니다. 이는 혈당 수치를 안정적으로 유지하고 체중 관리를 도와줍니다. 또한, 과일, 채소, 통곡물 등을 충분히 포함한 식단을 권장합니다.
#
# 3. **운동**: 규칙적인 운동은 혈당 조절에 도움이 될 수 있습니다. 단, 인슐린 주사의 필요성이 있는 경우 운동 계획을 세우는 것이 중요합니다.
#
# 4. **약물치료**: 일부 사람들에게는 경구혈당강하제를 사용할 수도 있지만, 이는 인슐린 주사가 더 효과적일 때만 고려됩니다. 약물치료는 주로 생활습관 개선보다 중증 케이스에서 시행됩니다.
#
# 5. **합병증 예방 및 관리**: 제1형 당뇨병 환자는 고혈압, 심장병, 신경병증 등 다양한 합병증 위험이 높으므로 정기적인 건강검진과 적절한 관리와 치료를 통해 이러한 문제를 예방해야 합니다.
#
# 각 개인의 상황에 따라 맞춤형 치료가 필요하며, 의료 전문가와의 긴밀한 협력이 중요합니다. 지속적인 모니터링과 교육이 필수적입니다.
#
# 각 환자의 상태에 맞는 최선의 치료 방법을 선택하기 위해 전문의와 상담하는 것이 좋습니다. 이를 통해 자신의 건강을 더욱 잘 관리할 수 있을 것입니다. 추가적인 정보나 궁금한 점이 있으면 언제든지 질문해 주세요!
# --------------------
#
# <bos><start_of_turn>user
# 고혈압인데 먹으면 안되는 거 있나요?<end_of_turn>
# <start_of_turn>model
#
# 고혈압이 있는 경우, 일부 음식은 피하는 것이 좋습니다. 다음은 고혈압 관리에 도움이 될 수 있는 몇 가지 권장되지 않는 식품입니다:
#
# 1. **나트륨(소금)**: 나트륨 섭취를 줄이는 것은 혈압 조절에 매우 중요합니다. 가공식품이나 인스턴트 식품에는 많은 양의 나트륨이 포함되어 있으므로 주의해야 합니다.
#
# 2. **포화지방과 트랜스지방**: 포화지방과 트랜스지방은 혈중 콜레스테롤을 높일 수 있으며, 이는 심장 질환 및 다른 건강 문제를 유발할 수 있습니다.
#
# 3. **설탕**: 과도한 설탕 섭취는 체내 염분 농도를 증가시켜 혈압을 올릴 수 있습니다.
#
# 4. **알코올**: 알코올은 혈압을 상승시킬 수 있으므로 적당히 마시는 것이 좋습니다.
#
# 5. **가공육류**: 가공육류는 일반적으로 높은 지방 함량을 가지고 있어 혈압 관리에 부정적인 영향을 미칠 수 있습니다.
#
# 6. **붉은 고기**: 소고기와 돼지고기는 비타민 B12와 같은 영양소가 부족할 수 있고, 특히 헴철분이 풍부하여 철분의 흡수를 방해할 수 있습니다.
#
# 7. **커피와 차**: 카페인은 혈압을 상승시킬 수 있으므로 커피나 차를 많이 마시는 것을 제한하는 것이 좋습니다.
#
# 각 개인의 건강 상태에 따라 이러한 식단 조언이 다를 수 있으니, 의사와 상담하거나 자신의 건강 상태에 맞는 식이 요법을 따르는 것이 가장 안전합니다. 또한, 규칙적으로 운동하고 건강한 생활 습관을 유지하면 고혈압 관리에 큰 도움이 됩니다. 필요하다면 전문 의료인의 도움을 받는 것도 좋은 방법입니다. 항상 자신에게 맞는 방법을 찾는 것이 중요합니다.
# --------------------
#
# <bos><start_of_turn>user
# 충치가 너무 아파요.<end_of_turn>
# <start_of_turn>model
#
# 치아에 충치가 생겼을 때 통증은 매우 불편할 수 있습니다. 치과 치료를 받으면서 통증이 줄어들고 완화될 수도 있지만, 심한 경우 통증이 계속되거나 악화되는 경우가 있을 수 있습니다. 이런 경우에는 치과의사와 상의하여 적절한 치료 계획을 세우는 것이 중요합니다. 통증이 심하거나 일상생활에 지장이 있다면 빠른 시일 내에 병원을 방문하시기 바랍니다. 필요하다면 진통제를 처방받기도 합니다. 만약 통증이 지속되거나 다른 증상이 동반된다면 반드시 전문가에게 상담하세요. 빠른 치료가 회복에 도움이 됩니다. 추가적인 질문이나 걱정이 있으면 언제든지 말씀해 주세요!
# --------------------
#
# <bos><start_of_turn>user
# 불안장애 환자의 식이는 어떻게 해야 되나요?<end_of_turn>
# <start_of_turn>model
#
# 불안장애 환자에게 적절한 식사는 신체적, 정신적 건강을 유지하는 데 매우 중요합니다. 다음은 불안장애 치료와 관련된 식이 요법에 대한 몇 가지 일반적인 조언입니다:
#
# 1. **균형 잡힌 영양소**: 다양한 과일과 채소를 포함한 균형 잡힌 식단을 제공하세요. 단백질(특히 생선, 콩류, 두부 등)도 충분히 섭취해야 합니다.
#
# 2. **식이 제한 금지**: 특정 음식이나 식품이 불안장애 증상을 악화시킬 수 있으므로, 이러한 음식을 피하도록 권장됩니다. 예를 들어, 카페인, 알코올, 당분이 많은 음식은 피하는 것이 좋습니다.
#
# 3. **수분 공급**: 물을 충분히 마시는 것은 필수적이며, 필요하다면 의사의 지시에 따라 수분을 조절할 수도 있습니다.
#
# 4. **식사 시간 관리**: 규칙적인 식사와 간식을 통해 에너지 수준을 유지하고 스트레스를 줄일 수 있도록 도와주세요.
#
# 5. **스트레스 완화**: 명상, 심호흡 운동, 취미 활동 등을 통해 스트레스를 효과적으로 해소할 수 있는 방법을 찾아보세요.
#
# 6. **전문가 상담**: 자신의 상태를 이해하고 맞춤형 식단 계획을 세우기 위해 전문가의 도움을 받는 것도 좋은 방법입니다.
#
# 7. **개별화된 접근**: 각 개인의 상황에 맞는 식단을 설계하기 위해 의료진과의 협력이 중요합니다.
#
# 이러한 가이드라인을 따르면서도 개인이 느끼는 불편함을 고려하여 점차적으로 변화를 시도해 보는 것이 바람직합니다. 항상 전문 의료인의 조언을 구하시고, 필요한 경우 약물치료나 다른 치료법을 병행하는 것이 도움이 될 수 있습니다. 불안장애는 꾸준한 관리가 필요하므로 장기적인 지원이 중요합니다.
# --------------------

# %%
model_name
# Out:
# 'gemma-3-1b-pt-MED_CPT'

# %%
model_save_dir = model_name+'-Instruct'

model.save_pretrained(model_save_dir, safe_serialization=False)
tokenizer.save_pretrained(model_save_dir)
# Out:
# ('gemma-3-1b-pt-MED_CPT-Instruct/tokenizer_config.json',
#  'gemma-3-1b-pt-MED_CPT-Instruct/special_tokens_map.json',
#  'gemma-3-1b-pt-MED_CPT-Instruct/chat_template.jinja',
#  'gemma-3-1b-pt-MED_CPT-Instruct/tokenizer.model',
#  'gemma-3-1b-pt-MED_CPT-Instruct/added_tokens.json',
#  'gemma-3-1b-pt-MED_CPT-Instruct/tokenizer.json')

# %%
from huggingface_hub import login
import locale
locale.getpreferredencoding = lambda: "UTF-8"

login('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')
# Write 권한 토큰 필요

# %%
username='NotoriousH2'

# 개인 계정 주소에 업로드하기
model.push_to_hub(f'{username}/{model_save_dir}_Instruct')
tokenizer.push_to_hub(f'{username}/{model_save_dir}_Instruct')

# %% [markdown]
# 현재 모델은 학습을 충분히 하지 않았으므로, 답변의 품질이 유동적입니다.

# %%
inputs = [
    "감기약 종류 좀 알려주세요.",
]*10
for i in inputs:
    print('Question:', i)
    print('Answer:', chain.invoke(i))
    print('---------')
# Out:
# Question: 감기약 종류 좀 알려주세요.
# Answer: 감기에는 여러 가지 약이 있으며, 각 약은 특정한 증상이나 원인에 따라 선택됩니다. 일반적으로 사용되는 감기약의 종류는 다음과 같습니다:
#
# 1. **항히스타민제**: 이 약물들은 알레르기 반응을 줄이는 데 도움을 줍니다. 코막힘과 가려움을 완화시키며, 두통과 불면증 같은 다른 증상을 유발할 수 있습니다.
#
# 2. **해열제 및 진통제**: 열을 내리고 통증을 완화하는 데 도움이 됩니다. 하지만 일부 해열제는 위장 장애를 일으킬 수 있으므로 주의가 필요합니다.
#
# 3. **소염진통제(NSAIDs)**: 염증을 줄이고 통증을 완화하며, 혈관을 확장시켜 부기를 줄입니다. 그러나 위장 출혈 위험이 있을 수 있어 일부 사람들에게는 피해야 할 경우도 있습니다.
#
# 4. **코피 제거제**: 코 막힌 것을 효과적으로 제거하여 호흡을 촉진하고 기침을 줄여줍니다.
#
# 5. **마데카솔**: 아세트아미노펜 성분이 포함되어 있어 통증을 완화시킵니다.
#
# 6. **알로푸리놀**: 항생제를 대체하거나 함께 사용할 때 사용되며, 주로 비염 치료에 사용됩니다.
#
# 7. **비스테로이드성 소염제(NSAIDs)와 스테로이드**: 두 약물이 결합된 형태로 사용될 수 있으며, 염증을 줄이고 통증을 완화하지만 장기 복용 시 부작용이 발생할 수 있습니다.
#
# 각 약물의 용법과 주의사항은 제품 라벨에 명확하게 표시되어 있으니, 처방받거나 구입하기 전에 해당 약의 설명서를 확인하는 것이 좋습니다. 또한, 어린이나 임산부는 반드시 의사와 상담 후 사용하는 것이 안전합니다. 건강 상태에 따라 적절한 약물을 선택하는 것이 중요합니다. 필요한 경우 전문 의료인의 조언을 받는 것도 좋은 방법입니다.
# ---------
# Question: 감기약 종류 좀 알려주세요.
# Answer: 감기에는 여러 가지 약이 있으며, 각 약은 특정한 증상이나 원인에 따라 선택됩니다. 일반적으로 사용되는 감기약의 종류는 다음과 같습니다:
#
# 1. **항히스타민제**: 이 약물들은 비타민 H를 포함한 물질을 통해 알레르기와 염증을 줄이는 데 도움을 줍니다. 대표적인 예로는 아세트아미노펜과 나프록센이 있습니다.
#
# 2. **해열제**: 열을 내리고 통증을 완화하는 데 도움이 됩니다. 예를 들어, 아스피린이나 이부프로펜 같은 약물이 있습니다.
#
# 3. **진통제**: 근육통이나 신경통을 완화하기 위해 사용되며, 주로 진통 효과가 있는 약입니다.
#
# 4. **소염제**: 염증을 줄여주는 역할을 하며, 통증과 부기를 줄이는 데 도움을 줍니다. 이 약물들은 항염증 성분이 포함되어 있습니다.
#
# 5. **코와 기도의 분비물 제거제**: 코나 입안의 가래를 제거하여 호흡을 쉽게 만들어 줍니다.
#
# 6. **마스크팩 및 수분 공급제**: 피부를 촉촉하게 유지하고 면역력을 높이기 위한 제품으로, 마스크팩은 특히 눈 주변에 자주 사용됩니다.
#
# 각 약물의 용법과 주의사항은 임의로 변경될 수 있으므로, 복용 전 반드시 의료 전문가와 상담하시기 바랍니다. 또한, 어린이에게는 적절한 약을 사용하는 것이 중요합니다. 필요하다면 의사나 약사와 상의하여 가장 적합한 치료 방법을 결정하세요. 건강을 지키는 것은 매우 중요하므로 올바른 정보를 바탕으로 관리하시길 바랍니다. 감사합니다!
# ---------
# Question: 감기약 종류 좀 알려주세요.
# Answer: 감기에는 여러 가지 약이 있으며, 각 약은 특정한 증상이나 원인에 따라 선택됩니다. 일반적으로 사용되는 감기약의 종류는 다음과 같습니다:
#
# 1. **항히스타민제**: 이 약물들은 알레르기 반응을 줄이는 데 도움을 줍니다. 코막힘과 가려움을 완화시키며, 두통과 불면증 같은 다른 증상을 유발할 수 있습니다.
#
# 2. **해열제**: 열을 내리고 몸을 따뜻하게 하는 역할을 합니다. 아스피린이나 나프록센 등이 대표적입니다.
#
# 3. **진해거담제**: 코를 막고 기침을 줄여주는 효과가 있습니다. 메틸렌오리자나 디클로페낙 등이 이에 해당합니다.
#
# 4. **소염진통제**: 염증을 줄이고 통증을 완화하는 데 도움이 됩니다. 이부프로펜이나 나프록센 등이 있습니다.
#
# 5. **해열 및 진통제**: 이 약물들은 동시에 작용하여 빠른 해열 및 진통 효과를 제공합니다. 예를 들어, 아세트아미노펜이나 이부프로펜 등이 있습니다.
#
# 6. **비스테로이드성 항염증제(NSAIDs)**: 소염작용을 하며, 통증과 염증을 줄이는 데 도움을 줍니다. 이부프로펜이나 나프록센 등이 포함됩니다.
#
# 각 약물의 성분과 용량은 개인마다 다르게 작용하므로, 복용하기 전에 의사의 지시를 꼭 따르는 것이 중요합니다. 또한, 임산부나 어린이에게는 금지된 약물이 있을 수 있으니 반드시 처방전에 명시되어 있는 정보를 확인하세요. 필요하다면 가까운 병원이나 약국에서 상담을 받는 것도 좋은 방법입니다. 건강한 생활습관과 충분한 휴식도 감기에 대비하는 데 중요한 요소입니다. 항상 적절한 치료와 관리가 중요합니다!
# ---------
# Question: 감기약 종류 좀 알려주세요.
# Answer: 감기에는 여러 가지 약이 있으며, 각 약은 특정한 증상이나 원인에 따라 선택됩니다. 다음은 일반적으로 사용되는 감기 치료제들입니다:
#
# 1. **항히스타민제**: 이 약물들은 알레르기 반응을 줄이는 데 도움을 줍니다. 코막힘과 가려움을 완화하는 데 효과적이며, 두통, 어지럼증 등의 부작용도 적습니다. 대표적인 예로는 아세트아미노펜, 나프록센 등이 있습니다.
#
# 2. **해열제**: 열을 내리고 통증을 완화하기 위해 사용합니다. 비스테로이드성 항염증제(NSAIDs)가 포함된 해열제는 염증을 줄이고 통증을 완화할 수 있지만 위장관 문제를 일으킬 수 있으므로 주의해야 합니다.
#
# 3. **진통제**: 근육통이나 신경통을 완화시키기 위한 진통제입니다. 주로 경구 형태로 제공되며, 위장 문제나 간 기능 이상 등 부작용 가능성이 있을 수 있습니다.
#
# 4. **소염진통제**: 염증을 줄여주는 역할을 하며, 통증과 발적을 감소시킵니다. NSAIDs를 포함한 소염진통제는 심혈관계 질환 위험이 증가할 수 있기 때문에 주의가 필요합니다.
#
# 5. **코피 제거제**: 코의 점액을 제거하여 코막힘을 줄입니다. 이는 보통 비타민 C와 같은 성분을 포함하고 있어 부작용이 적습니다.
#
# 6. **비마약성 진통제(Tylenol)**: 일반적인 오피오이드 대체제로, 비교적 안전하게 사용할 수 있는 약으로 알려져 있습니다.
#
# 각 약물의 용법 및 주의사항은 제품 라벨에서 확인하거나 의사에게 상담 후 복용하는 것이 중요합니다. 특히 고령자, 임산부, 소아 등 취약 계층에서는 더욱 신중한 접근이 필요합니다. 항상 처방받은 대로 복용하시고, 이상 증상이 나타날 경우 즉시 의료 전문가와 상의하세요. 건강을 유지하는 것은 매우 중요하므로 정기적으로 건강 상태를 체크하는 것도 좋습니다.
# ---------
# Question: 감기약 종류 좀 알려주세요.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-531966367.py in <cell line: 0>()
#       4 for i in inputs:
#       5     print('Question:', i)
# ----> 6     print('Answer:', chain.invoke(i))
#       7     print('---------')
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/runnables/base.py in invoke(self, input, config, **kwargs)
#    3080                         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3081                     else:
# -> 3082                         input_ = context.run(step.invoke, input_, config)
#    3083         # finish the root run
#    3084         except BaseException as e:
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     391         return cast(
#     392             "ChatGeneration",
# --> 393             self.generate_prompt(
#     394                 [self._convert_input(input)],
#     395                 stop=stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1017     ) -> LLMResult:
#    1018         prompt_messages = [p.to_messages() for p in prompts]
# -> 1019         return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#    1020
#    1021     @override
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     835             try:
#     836                 results.append(
# --> 837                     self._generate_with_cache(
#     838                         m,
#     839                         stop=stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in _generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1083             result = generate_from_stream(iter(chunks))
#    1084         elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1085             result = self._generate(
#    1086                 messages, stop=stop, run_manager=run_manager, **kwargs
#    1087             )
#
# /usr/local/lib/python3.12/dist-packages/langchain_huggingface/chat_models/huggingface.py in _generate(self, messages, stop, run_manager, stream, **kwargs)
#     584             )
#     585             return generate_from_stream(stream_iter)
# --> 586         llm_result = self.llm._generate(
#     587             prompts=[llm_input], stop=stop, run_manager=run_manager, **kwargs
#     588         )
#
# /usr/local/lib/python3.12/dist-packages/langchain_huggingface/llms/huggingface_pipeline.py in _generate(self, prompts, stop, run_manager, **kwargs)
#     321
#     322             # Process batch of prompts
# --> 323             responses = self.pipeline(
#     324                 batch_prompts,
#     325                 **pipeline_kwargs,
#
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/text_generation.py in __call__(self, text_inputs, **kwargs)
#     330                     else:
#     331                         return super().__call__(list(chats), **kwargs)
# --> 332         return super().__call__(text_inputs, **kwargs)
#     333
#     334     def preprocess(
#
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1446                     inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1447                 )
# -> 1448                 outputs = list(final_iterator)
#    1449                 return outputs
#    1450             else:
#
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/pt_utils.py in __next__(self)
#     124
#     125         # We're out of items within a batch
# --> 126         item = next(self.iterator)
#     127         processed = self.infer(item, **self.params)
#     128         # We now have a batch of "inferred things".
#
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/pt_utils.py in __next__(self)
#     125         # We're out of items within a batch
#     126         item = next(self.iterator)
# --> 127         processed = self.infer(item, **self.params)
#     128         # We now have a batch of "inferred things".
#     129         if self.loader_batch_size is not None:
#
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/base.py in forward(self, model_inputs, **forward_params)
#    1372                 with inference_context():
#    1373                     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1374                     model_outputs = self._forward(model_inputs, **forward_params)
#    1375                     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1376             else:
#
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/text_generation.py in _forward(self, model_inputs, **generate_kwargs)
#     430             generate_kwargs["generation_config"] = self.generation_config
#     431
# --> 432         output = self.model.generate(input_ids=input_ids, attention_mask=attention_mask, **generate_kwargs)
#     433
#     434         if isinstance(output, ModelOutput):
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     118     def decorate_context(*args, **kwargs):
#     119         with ctx_factory():
# --> 120             return func(*args, **kwargs)
#     121
#     122     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2537         elif generation_mode in (GenerationMode.SAMPLE, GenerationMode.GREEDY_SEARCH):
#    2538             # 11. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2539             result = self._sample(
#    2540                 input_ids,
#    2541                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    2868                 is_prefill = False
#    2869             else:
# -> 2870                 outputs = model_forward(**model_inputs, return_dict=True)
#    2871
#    2872             # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#     938         if return_dict_passed is not None:
#     939             return_dict = return_dict_passed
# --> 940         output = func(self, *args, **kwargs)
#     941         if not return_dict and not isinstance(output, tuple):
#     942             output = output.to_tuple()
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/gemma3/modeling_gemma3.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, cache_position, logits_to_keep, **kwargs)
#     646         )
#     647         # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# --> 648         outputs: BaseModelOutputWithPast = self.model(
#     649             input_ids=input_ids,
#     650             attention_mask=attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#    1062                         monkey_patched_layers.append((module, original_forward))
#    1063
# -> 1064         outputs = func(self, *args, **kwargs)
#    1065         # Restore original forward methods
#    1066         for module, original_forward in monkey_patched_layers:
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/gemma3/modeling_gemma3.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, cache_position, **kwargs)
#     534             # Create the masks
#     535             causal_mask_mapping = {
# --> 536                 "full_attention": create_causal_mask(**mask_kwargs),
#     537                 "sliding_attention": create_sliding_window_causal_mask(**mask_kwargs),
#     538             }
#
# /usr/local/lib/python3.12/dist-packages/transformers/masking_utils.py in create_causal_mask(config, input_embeds, attention_mask, cache_position, past_key_values, position_ids, or_mask_function, and_mask_function)
#     820
#     821     # We now create the mask
# --> 822     causal_mask = mask_interface(
#     823         batch_size=batch_size,
#     824         cache_position=cache_position,
#
# /usr/local/lib/python3.12/dist-packages/transformers/masking_utils.py in eager_mask(batch_size, cache_position, kv_length, kv_offset, mask_function, attention_mask, dtype, **kwargs)
#     506     # The masks for eager attention are simply boolean mask from sdpa, casted to 0 and -inf
#     507     _ = kwargs.pop("allow_is_causal_skip", None)
# --> 508     mask = sdpa_mask(
#     509         batch_size=batch_size,
#     510         cache_position=cache_position,
#
# /usr/local/lib/python3.12/dist-packages/transformers/masking_utils.py in sdpa_mask_recent_torch(batch_size, cache_position, kv_length, kv_offset, mask_function, attention_mask, local_size, allow_is_causal_skip, **kwargs)
#     390     # We don't need to add an offset to the mask_function either, as we vmap directly the correct indices for k and kv indices
#     391     with TransformGetItemToIndex():
# --> 392         causal_mask = _vmap_for_bhqkv(mask_function)(batch_arange, head_arange, cache_position, kv_arange)
#     393
#     394     return causal_mask
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/apis.py in wrapped(*args, **kwargs)
#     200
#     201     def wrapped(*args, **kwargs):
# --> 202         return vmap_impl(
#     203             func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs
#     204         )
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/vmap.py in vmap_impl(func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs)
#     332
#     333     # If chunk_size is not specified.
# --> 334     return _flat_vmap(
#     335         func,
#     336         batch_size,
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/vmap.py in _flat_vmap(func, batch_size, flat_in_dims, flat_args, args_spec, out_dims, randomness, **kwargs)
#     482             flat_in_dims, flat_args, vmap_level, args_spec
#     483         )
# --> 484         batched_outputs = func(*batched_inputs, **kwargs)
#     485         return _unwrap_batched(batched_outputs, out_dims, vmap_level, batch_size, func)
#     486
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/apis.py in wrapped(*args, **kwargs)
#     200
#     201     def wrapped(*args, **kwargs):
# --> 202         return vmap_impl(
#     203             func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs
#     204         )
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/vmap.py in vmap_impl(func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs)
#     332
#     333     # If chunk_size is not specified.
# --> 334     return _flat_vmap(
#     335         func,
#     336         batch_size,
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/vmap.py in _flat_vmap(func, batch_size, flat_in_dims, flat_args, args_spec, out_dims, randomness, **kwargs)
#     482             flat_in_dims, flat_args, vmap_level, args_spec
#     483         )
# --> 484         batched_outputs = func(*batched_inputs, **kwargs)
#     485         return _unwrap_batched(batched_outputs, out_dims, vmap_level, batch_size, func)
#     486
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/apis.py in wrapped(*args, **kwargs)
#     200
#     201     def wrapped(*args, **kwargs):
# --> 202         return vmap_impl(
#     203             func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs
#     204         )
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/vmap.py in vmap_impl(func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs)
#     332
#     333     # If chunk_size is not specified.
# --> 334     return _flat_vmap(
#     335         func,
#     336         batch_size,
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/vmap.py in _flat_vmap(func, batch_size, flat_in_dims, flat_args, args_spec, out_dims, randomness, **kwargs)
#     482             flat_in_dims, flat_args, vmap_level, args_spec
#     483         )
# --> 484         batched_outputs = func(*batched_inputs, **kwargs)
#     485         return _unwrap_batched(batched_outputs, out_dims, vmap_level, batch_size, func)
#     486
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/apis.py in wrapped(*args, **kwargs)
#     200
#     201     def wrapped(*args, **kwargs):
# --> 202         return vmap_impl(
#     203             func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs
#     204         )
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/vmap.py in vmap_impl(func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs)
#     332
#     333     # If chunk_size is not specified.
# --> 334     return _flat_vmap(
#     335         func,
#     336         batch_size,
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/vmap.py in _flat_vmap(func, batch_size, flat_in_dims, flat_args, args_spec, out_dims, randomness, **kwargs)
#     482             flat_in_dims, flat_args, vmap_level, args_spec
#     483         )
# --> 484         batched_outputs = func(*batched_inputs, **kwargs)
#     485         return _unwrap_batched(batched_outputs, out_dims, vmap_level, batch_size, func)
#     486
#
# /usr/local/lib/python3.12/dist-packages/transformers/masking_utils.py in and_mask(batch_idx, head_idx, q_idx, kv_idx)
#      52         result = q_idx.new_ones((), dtype=torch.bool)
#      53         for mask in mask_functions:
# ---> 54             result = result & mask(batch_idx, head_idx, q_idx, kv_idx).to(result.device)
#      55         return result
#      56
#
# /usr/local/lib/python3.12/dist-packages/transformers/masking_utils.py in inner_mask(batch_idx, head_idx, q_idx, kv_idx)
#     140         # we cannot pad it here in the mask_function as we don't know the final size, and we cannot try/except, as it is not
#     141         # vectorizable on accelerator devices
# --> 142         return padding_mask[batch_idx, kv_idx]
#     143
#     144     return inner_mask
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/_trace_wrapped_higher_order_op.py in __torch_function__(self, func, types, args, kwargs)
#     139             index_args = pytree.tree_leaves(args[1])
#     140             if all(isinstance(x, torch.Tensor) for x in index_args):
# --> 141                 return mod_index(args[0], index_args)
#     142         return func(*args, **(kwargs or {}))
#     143
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py in apply(cls, *args, **kwargs)
#     584             )
#     585
# --> 586         return custom_function_call(cls, *args, **kwargs)
#     587
#     588     @staticmethod
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/autograd_function.py in __call__(self, autograd_function, *args, **kwargs)
#      47         # and only traces the forward pass.
#      48         if torch._C._are_functorch_transforms_active():
# ---> 49             return super().__call__(autograd_function, *args, **kwargs)
#      50         return autograd_function.apply(*args, **kwargs)
#      51
#
# /usr/local/lib/python3.12/dist-packages/torch/_ops.py in __call__(self, *args, **kwargs)
#     522             )
#     523
# --> 524         return wrapper()
#     525
#     526     # NOTE [HigherOrderOprator Schema]
#
# /usr/local/lib/python3.12/dist-packages/torch/_ops.py in wrapper()
#     518
#     519             dispatch_key_set = _compute_keyset(args, kwargs, self.non_fallthrough_keys)
# --> 520             return self.dispatch(
#     521                 dispatch_key_set.highestPriorityTypeId(), *args, **kwargs
#     522             )
#
# /usr/local/lib/python3.12/dist-packages/torch/_ops.py in dispatch(self, dispatch_key, *args, **kwargs)
#     381
#     382         if dispatch_key == DispatchKey.FuncTorchDynamicLayerFrontMode:
# --> 383             return dispatch_functorch(self, args, kwargs)
#     384
#     385         if dispatch_key == DispatchKey.Python:
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/pyfunctorch.py in dispatch_functorch(op, args, kwargs)
#     310         torch.Tensor, torch._C._functorch.unwrap_if_dead, (args, kwargs)
#     311     )
# --> 312     return interpreter.process(op, args, kwargs)
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/pyfunctorch.py in process(self, op, args, kwargs)
#     137     def process(self, op, args, kwargs):
#     138         kernel = op.functorch_table[TransformType.Vmap]
# --> 139         return kernel(self, *args, **kwargs)
#     140
#     141     def batch_size(self):
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/autograd_function.py in custom_function_call_vmap(interpreter, autograd_function, *operands, **kwargs)
#     298                 f"https://pytorch.org/docs/main/notes/extending.func.html"
#     299             )
# --> 300         return custom_function_call_vmap_generate_rule(
#     301             interpreter, autograd_function, *operands
#     302         )
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/autograd_function.py in custom_function_call_vmap_generate_rule(interpreter, autograd_function, *operands)
#     382     )
#     383     with interpreter.lower():
# --> 384         outputs = custom_function_call(vmapped_function, *unwrapped_operands)
#     385
#     386     assert isinstance(outputs, tuple)
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/autograd_function.py in __call__(self, autograd_function, *args, **kwargs)
#      47         # and only traces the forward pass.
#      48         if torch._C._are_functorch_transforms_active():
# ---> 49             return super().__call__(autograd_function, *args, **kwargs)
#      50         return autograd_function.apply(*args, **kwargs)
#      51
#
# /usr/local/lib/python3.12/dist-packages/torch/_ops.py in __call__(self, *args, **kwargs)
#     522             )
#     523
# --> 524         return wrapper()
#     525
#     526     # NOTE [HigherOrderOprator Schema]
#
# /usr/local/lib/python3.12/dist-packages/torch/_ops.py in wrapper()
#     518
#     519             dispatch_key_set = _compute_keyset(args, kwargs, self.non_fallthrough_keys)
# --> 520             return self.dispatch(
#     521                 dispatch_key_set.highestPriorityTypeId(), *args, **kwargs
#     522             )
#
# /usr/local/lib/python3.12/dist-packages/torch/_ops.py in dispatch(self, dispatch_key, *args, **kwargs)
#     381
#     382         if dispatch_key == DispatchKey.FuncTorchDynamicLayerFrontMode:
# --> 383             return dispatch_functorch(self, args, kwargs)
#     384
#     385         if dispatch_key == DispatchKey.Python:
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/pyfunctorch.py in dispatch_functorch(op, args, kwargs)
#     310         torch.Tensor, torch._C._functorch.unwrap_if_dead, (args, kwargs)
#     311     )
# --> 312     return interpreter.process(op, args, kwargs)
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/pyfunctorch.py in process(self, op, args, kwargs)
#     137     def process(self, op, args, kwargs):
#     138         kernel = op.functorch_table[TransformType.Vmap]
# --> 139         return kernel(self, *args, **kwargs)
#     140
#     141     def batch_size(self):
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/autograd_function.py in custom_function_call_vmap(interpreter, autograd_function, *operands, **kwargs)
#     298                 f"https://pytorch.org/docs/main/notes/extending.func.html"
#     299             )
# --> 300         return custom_function_call_vmap_generate_rule(
#     301             interpreter, autograd_function, *operands
#     302         )
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/autograd_function.py in custom_function_call_vmap_generate_rule(interpreter, autograd_function, *operands)
#     382     )
#     383     with interpreter.lower():
# --> 384         outputs = custom_function_call(vmapped_function, *unwrapped_operands)
#     385
#     386     assert isinstance(outputs, tuple)
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/autograd_function.py in __call__(self, autograd_function, *args, **kwargs)
#      47         # and only traces the forward pass.
#      48         if torch._C._are_functorch_transforms_active():
# ---> 49             return super().__call__(autograd_function, *args, **kwargs)
#      50         return autograd_function.apply(*args, **kwargs)
#      51
#
# /usr/local/lib/python3.12/dist-packages/torch/_ops.py in __call__(self, *args, **kwargs)
#     522             )
#     523
# --> 524         return wrapper()
#     525
#     526     # NOTE [HigherOrderOprator Schema]
#
# /usr/local/lib/python3.12/dist-packages/torch/_ops.py in wrapper()
#     518
#     519             dispatch_key_set = _compute_keyset(args, kwargs, self.non_fallthrough_keys)
# --> 520             return self.dispatch(
#     521                 dispatch_key_set.highestPriorityTypeId(), *args, **kwargs
#     522             )
#
# /usr/local/lib/python3.12/dist-packages/torch/_ops.py in dispatch(self, dispatch_key, *args, **kwargs)
#     381
#     382         if dispatch_key == DispatchKey.FuncTorchDynamicLayerFrontMode:
# --> 383             return dispatch_functorch(self, args, kwargs)
#     384
#     385         if dispatch_key == DispatchKey.Python:
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/pyfunctorch.py in dispatch_functorch(op, args, kwargs)
#     310         torch.Tensor, torch._C._functorch.unwrap_if_dead, (args, kwargs)
#     311     )
# --> 312     return interpreter.process(op, args, kwargs)
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/pyfunctorch.py in process(self, op, args, kwargs)
#     137     def process(self, op, args, kwargs):
#     138         kernel = op.functorch_table[TransformType.Vmap]
# --> 139         return kernel(self, *args, **kwargs)
#     140
#     141     def batch_size(self):
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/autograd_function.py in custom_function_call_vmap(interpreter, autograd_function, *operands, **kwargs)
#     298                 f"https://pytorch.org/docs/main/notes/extending.func.html"
#     299             )
# --> 300         return custom_function_call_vmap_generate_rule(
#     301             interpreter, autograd_function, *operands
#     302         )
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/autograd_function.py in custom_function_call_vmap_generate_rule(interpreter, autograd_function, *operands)
#     382     )
#     383     with interpreter.lower():
# --> 384         outputs = custom_function_call(vmapped_function, *unwrapped_operands)
#     385
#     386     assert isinstance(outputs, tuple)
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/autograd_function.py in __call__(self, autograd_function, *args, **kwargs)
#      47         # and only traces the forward pass.
#      48         if torch._C._are_functorch_transforms_active():
# ---> 49             return super().__call__(autograd_function, *args, **kwargs)
#      50         return autograd_function.apply(*args, **kwargs)
#      51
#
# /usr/local/lib/python3.12/dist-packages/torch/_ops.py in __call__(self, *args, **kwargs)
#     522             )
#     523
# --> 524         return wrapper()
#     525
#     526     # NOTE [HigherOrderOprator Schema]
#
# /usr/local/lib/python3.12/dist-packages/torch/_ops.py in wrapper()
#     518
#     519             dispatch_key_set = _compute_keyset(args, kwargs, self.non_fallthrough_keys)
# --> 520             return self.dispatch(
#     521                 dispatch_key_set.highestPriorityTypeId(), *args, **kwargs
#     522             )
#
# /usr/local/lib/python3.12/dist-packages/torch/_ops.py in dispatch(self, dispatch_key, *args, **kwargs)
#     381
#     382         if dispatch_key == DispatchKey.FuncTorchDynamicLayerFrontMode:
# --> 383             return dispatch_functorch(self, args, kwargs)
#     384
#     385         if dispatch_key == DispatchKey.Python:
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/pyfunctorch.py in dispatch_functorch(op, args, kwargs)
#     310         torch.Tensor, torch._C._functorch.unwrap_if_dead, (args, kwargs)
#     311     )
# --> 312     return interpreter.process(op, args, kwargs)
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/pyfunctorch.py in process(self, op, args, kwargs)
#     137     def process(self, op, args, kwargs):
#     138         kernel = op.functorch_table[TransformType.Vmap]
# --> 139         return kernel(self, *args, **kwargs)
#     140
#     141     def batch_size(self):
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/autograd_function.py in custom_function_call_vmap(interpreter, autograd_function, *operands, **kwargs)
#     298                 f"https://pytorch.org/docs/main/notes/extending.func.html"
#     299             )
# --> 300         return custom_function_call_vmap_generate_rule(
#     301             interpreter, autograd_function, *operands
#     302         )
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/autograd_function.py in custom_function_call_vmap_generate_rule(interpreter, autograd_function, *operands)
#     382     )
#     383     with interpreter.lower():
# --> 384         outputs = custom_function_call(vmapped_function, *unwrapped_operands)
#     385
#     386     assert isinstance(outputs, tuple)
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/autograd_function.py in __call__(self, autograd_function, *args, **kwargs)
#      48         if torch._C._are_functorch_transforms_active():
#      49             return super().__call__(autograd_function, *args, **kwargs)
# ---> 50         return autograd_function.apply(*args, **kwargs)
#      51
#      52
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py in apply(cls, *args, **kwargs)
#     574             # See NOTE: [functorch vjp and autograd interaction]
#     575             args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 576             return super().apply(*args, **kwargs)  # type: ignore[misc]
#     577
#     578         if not is_setup_ctx_defined:
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/autograd_function.py in forward(*operands)
#     398 def vmapify_autograd_function(autograd_function, in_dims, batch_size, randomness):
#     399     def forward(*operands):
# --> 400         outputs, out_dims = restore_vmap(
#     401             autograd_function.forward, in_dims, batch_size, randomness
#     402         )(*operands)
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/vmap.py in inner(*args, **kwargs)
#     510         with vmap_increment_nesting(batch_size, randomness) as vmap_level:
#     511             batched_inputs = wrap_batched(args, in_dims, vmap_level)
# --> 512             batched_outputs = func(*batched_inputs, **kwargs)
#     513             return unwrap_batched(batched_outputs, vmap_level)
#     514
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/autograd_function.py in forward(*operands)
#     398 def vmapify_autograd_function(autograd_function, in_dims, batch_size, randomness):
#     399     def forward(*operands):
# --> 400         outputs, out_dims = restore_vmap(
#     401             autograd_function.forward, in_dims, batch_size, randomness
#     402         )(*operands)
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/vmap.py in inner(*args, **kwargs)
#     509     def inner(*args, **kwargs):
#     510         with vmap_increment_nesting(batch_size, randomness) as vmap_level:
# --> 511             batched_inputs = wrap_batched(args, in_dims, vmap_level)
#     512             batched_outputs = func(*batched_inputs, **kwargs)
#     513             return unwrap_batched(batched_outputs, vmap_level)
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/vmap.py in wrap_batched(args, bdims, level)
#     520     flat_bdims = _broadcast_to_and_flatten(bdims, spec)
#     521     assert flat_bdims is not None
# --> 522     result = _create_batched_inputs(flat_bdims, flat_args, level, spec)
#     523     return result
#     524
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/vmap.py in _create_batched_inputs(flat_in_dims, flat_args, vmap_level, args_spec)
#     152
#     153
# --> 154 def _create_batched_inputs(
#     155     flat_in_dims: list[Any], flat_args: list[Any], vmap_level: int, args_spec
#     156 ) -> tuple:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Catastrophic Forgetting과 일반화
#
# 의료 데이터가 아닌 데이터를 일부 학습했기 때문에, 일반적인 질문에 대해서도 답변할 수 있습니다.
# 편향된 데이터만으로 풀 파인 튜닝을 하는 경우에는 기존의 지식을 잘 출력하지 못하게 됩니다.

# %%
inputs = [
    "사과는 왜 빨간가요?",
    "저는 사과 12개가 있었는데, 친구에게 절반을 나눠줬어요. 남은 사과는 몇 개인가요?",
    "곰과 사자 중 누가 더 큰가요?",
]
for i in inputs:
    print('Question:', i)
    print('Answer:', chain.invoke(i))
# Out:
# Question: 사과는 왜 빨간가요?
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Answer: 사과의 색깔이 빨간 이유는 주로 자연 선택과 유전적 요인에 기인합니다. 사과는 붉은색을 가진 꽃을 피우는 식물 중 하나로, 이 과정에서 일부 씨앗이 적절한 환경에서 발아하여 성장하게 됩니다. 이러한 과정을 통해 사과의 형질이 지속적으로 유지됩니다.
#
# 또한, 사과의 과육의 색상은 주로 유전자 변이가 작용하는 결과입니다. 특정 유전자가 발현되면서 사과의 색소가 형성되고, 이는 시간이 지남에 따라 계속해서 증가하거나 감소할 수 있습니다. 이러한 변화는 자연 선택의 결과이며, 시간이 지나면서 사과의 외형이나 색상이 점차 진해지는 경향이 있습니다.
#
# 따라서 사과의 색깔은 주로 유전적 특성 때문이며, 환경 조건에 의해 영향을 받지 않는 것이 일반적인 관행입니다. 다만, 사과의 색상 차이는 농업 기술이나 재배 방식에 따라 달라질 수도 있으니, 이는 지역별 또는 농부의 노력에 따라 다를 수 있습니다.
#
# 이러한 이유들 때문에 사과의 색깔은 자연스럽게 빨간색으로 결정되는 것입니다. 과학적 연구나 육종 작업에서는 이러한 현상을 이해하고 개선하기 위한 다양한 방법을 모색하고 있습니다. 그러나 사과의 색깔 자체는 생태학적 측면에서 매우 중요한 역할을 하는 것으로 여겨집니다.
#
# 이와 관련된 더 많은 정보는 학술 논문이나 관련 자료를 참고하면 도움이 될 것입니다. 예를 들어, 사과의 색깔이 어떻게 결정되는지에 대한 구체적인 설명은 다음과 같습니다:
#
# - **유전적 요소**: 사과의 색소는 주로 유전자에 의해 결정되며, 특정 유전자의 발현 정도에 따라 색소가 생성됩니다.
#
# - **환경적 요인**: 사과의 색깔은 또한 주변 환경, 햇빛, 온도 등의 물리적 조건에 의해 영향을 받을 수 있습니다.
#
# 이러한 이유들로 인해 사과의 색깔은 자연 선택과 유전적 다양성에 의해 결정됩니다. 추가적인 정보를 원하시면 해당 분야의 전문가나 관련 문헌을 참조하시기 바랍니다.
#
# 이 외에도 사과의 맛이나 질감 등도 자연 선택의 결과일 수 있으며, 이러한 요소들이 복합적으로 작용하여 최종적으로 사과의 색깔을 결정한다고 할 수 있습니다. 따라서 사과의 색깔은 단순히 빛깔일 뿐만 아니라 여러 가지 다른 측면에서도 고려되어야 합니다.
#
# 궁금하신 점이 있으면 추가 질문해 주세요! 감사합니다. :)
# Question: 저는 사과 12개가 있었는데, 친구에게 절반을 나눠줬어요. 남은 사과는 몇 개인가요?
# Answer: 사과 12개를 친구에게 나누어준 후 남은 사과는 총 6개입니다.
#
# 이 계산식으로 확인해 보세요:
# - 사과 12개 - 친구에게 나누어준 사과 = 6개
# - 나머지 사과 = 6개
#
# 따라서, 친구에게 남은 사과는 6개입니다.
#
# 이런 방식으로도 계산할 수 있습니다:
# - 사과 12개 - 친구에게 나누어준 사과 + 나머지 사과 = 6개
#
# 이 방법 중 하나를 선택하여 계산해보세요! :)
# Question: 곰과 사자 중 누가 더 큰가요?
# Answer: 곰과 사자는 둘 다 매우 크고 거대한 동물입니다. 일반적으로 곰은 체중이 약 100~250kg 정도이고, 사자는 약 1톤에서 3톤까지 나옵니다. 따라서 두 동물의 평균적인 무게를 비교하면, 곰은 사자와 비슷한 수준의 크기를 가집니다. 그러나 정확한 비교는 각각의 개체에 따라 달라질 수 있습니다. 예를 들어, 특정 종의 곰이나 사자의 경우, 그들의 크기는 환경적 요인(예: 서식지, 먹이 등)에 크게 영향을 받을 수 있습니다. 이러한 이유로 두 동물을 직접 비교하기보다는 일반적인 정보를 참고하는 것이 좋습니다. 만약 특정한 상황이나 기준을 원하신다면, 구체적으로 어떤 기준으로 비교하고 싶으신지에 대해 말씀해 주시면 도움이 될 것입니다. 감사합니다! 😊

# %% [markdown]
# 코랩에서 실행하시는 경우, `런타임 --> 세션 다시 시작`
# `런타임 --> 런타임 연결 해제 및 삭제`
# 를 실행해야 무료 사용량을 절약할 수 있습니다.

# %%
import torch
from transformers import AutoModelForCausalLM,AutoTokenizer

model_id="NotoriousH2/gemma-3-1b-pt-MED_CPT-Instruct_CPT"
# 모델의 주소
# (로컬 주소도 가능)

model_name = model_id.split('/')[1]
print("## MODEL:", model_name)

tokenizer = AutoTokenizer.from_pretrained(
    model_id,
)
model = AutoModelForCausalLM.from_pretrained(model_id,
                                             torch_dtype='auto',
                                             device_map="auto",
                                             attn_implementation="eager",
                                            )


from transformers import pipeline

# 파인 튜닝 모델이므로, 공식 파리미터를 따를 필요는 없음

gen_config = dict(
    do_sample=True,
    max_new_tokens=1024,
    repetition_penalty = 1.1,
    temperature = 0.1,
    top_p = 0.95,
    top_k = 64,

)

pipe = pipeline("text-generation", model=model, tokenizer=tokenizer, return_full_text=False,
                **gen_config)


base_llm = HuggingFacePipeline(pipeline=pipe, pipeline_kwargs=gen_config)

llm = ChatHuggingFace(llm=base_llm, tokenizer=tokenizer)
# Out:
# ## MODEL: gemma-3-1b-pt-MED_CPT-Instruct_CPT
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.69M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/2.00G [00:00<?, ?B/s]
# The following generation flags are not valid and may be ignored: ['cache_implementation']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# generation_config.json:   0%|          | 0.00/233 [00:00<?, ?B/s]
# Device set to use cuda:0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3092256171.py in <cell line: 0>()
#      37
#      38
# ---> 39 base_llm = HuggingFacePipeline(pipeline=pipe, pipeline_kwargs=gen_config)
#      40
#      41 llm = ChatHuggingFace(llm=base_llm, tokenizer=tokenizer)
#
# NameError: name 'HuggingFacePipeline' is not defined
