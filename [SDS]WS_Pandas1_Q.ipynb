# %% [markdown]
# ## Pandas 자료 구조 생성 및 조회 실습

# %%
import pandas as pd

# %% [markdown]
# ### Series 생성 및 값 조회

# %%
# 리스트 [1,2,3,4,5]를 5개 요소를 갖는 Series로 생성하세요.
s = pd.Series([1,2,3,4,5])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# 값 4를 추출하세요.
s[3]
# Out:
# np.int64(4)

# %%
# 값 3~4를 추출하세요.
s[2:4]
# Out:
# 2    3
# 3    4
# dtype: int64

# %%
# 리스트 [1,2,3,4,5]를 이용하여 시리즈를 생성하되, index를 ['A', 'B', 'C', 'D', 'E']로 지정하여 생성하세요.
s = pd.Series([1,2,3,4,5], index=['A', 'B', 'C', 'D', 'E'])
s
# Out:
# A    1
# B    2
# C    3
# D    4
# E    5
# dtype: int64

# %%
# 값 4를 문자열 인덱스를 이용하여 추출하세요.
# Out:
# np.int64(4)

# %%
# 값 4를 양의 정수 인덱스를 이용하여 추출하세요.
# Out:
# C:\Users\Mana\AppData\Local\Temp\ipykernel_61700\2602253208.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s[3]
# np.int64(4)

# %%
# 값 4를 음의 정수 인덱스를 이용하여 추출하세요.
# Out:
# C:\Users\Mana\AppData\Local\Temp\ipykernel_61700\1715272660.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s[-2]
# np.int64(4)

# %%
# 값 3~4를 문자열 인덱스를 이용하여 추출하세요.
# Out:
# C    3
# D    4
# dtype: int64

# %%
# 값 3~4를 양의 정수 인덱스를 이용하여 추출하세요.
# Out:
# C    3
# D    4
# dtype: int64

# %%
# 값 3~4를 음의 정수 인덱스를 이용하여 추출하세요.
# Out:
# C    3
# D    4
# dtype: int64

# %%
# 값 1, 3, 5를 추출하세요.
# Out:
# A    1
# C    3
# E    5
# dtype: int64

# %% [markdown]
# ### Series 속성 조회

# %%
# 1,2,3,4,5의 값을 갖고 인덱스가 A B C D E인 시리즈 s를 생성하세요.
# Out:
# A    1
# B    2
# C    3
# D    4
# E    5
# dtype: int64

# %%
# s의 차원 크기(rank)를 조회하세요.
# Out:
# 1

# %%
# s의 shape을 조회하세요.
# Out:
# (5,)

# %%
# s의 요소 수를 조회하세요
# Out:
# 5

# %%
# s의 index를 조회하세요.
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
# s의 index 중 첫 번째 index를 출력하세요.
# Out:
# 'A'

# %%
# s의 index 중 마지막 index를 출력하세요.
# Out:
# 'E'

# %%
# s의 index 중 'B'~'D'까지의 인덱스를 모두 추출하세요.
# Out:
# Index(['B', 'C', 'D'], dtype='object')

# %%
# s의 values를 조회하세요.
# Out:
# array([1, 2, 3, 4, 5])

# %%
# s의 데이터 타입을 조회하세요.
# Out:
# dtype('int64')

# %% [markdown]
# ### Series 값 수정 및 추가

# %%
# 그대로 실행하세요.
s1 = pd.Series([1,2,3,4,5], index=list('ABCDE'))
s2 = pd.Series([1,2,3,4,5])
display(s1)
display(s2)
# Out:
# A    1
# B    2
# C    3
# D    4
# E    5
# dtype: int64
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# s1의 c 인덱스의 값(3)을 30으로 수정하세요.
# Out:
# A     1
# B     2
# C    30
# D     4
# E     5
# dtype: int64

# %%
# s2의 세 번째 값(3)을 10으로 나눠서 저장하세요.
# Out:
# C:\Users\Mana\AppData\Local\Temp\ipykernel_61700\982836785.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.3' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   s2[2] = s2[2]/10
# 0    1.0
# 1    2.0
# 2    0.3
# 3    4.0
# 4    5.0
# dtype: float64

# %%
# s1과 s2를 더해서 s3에 저장하세요.
# Out:
# A   NaN
# B   NaN
# C   NaN
# D   NaN
# E   NaN
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# dtype: float64

# %%
# s2의 index를 A B C D E로 변경한 후 다시 더해서 s4에 저장하세요.
# Out:
# A     2.0
# B     4.0
# C    30.3
# D     8.0
# E    10.0
# dtype: float64

# %%
# s1 전체에 10을 더하세요.
# Out:
# A    11
# B    12
# C    40
# D    14
# E    15
# dtype: int64

# %%
# s2 전체에 10을 곱하세요.
# Out:
# A    10.0
# B    20.0
# C     3.0
# D    40.0
# E    50.0
# dtype: float64

# %%
# s1이 s2보다 큰지 비교하세요.
# Out:
# A     True
# B    False
# C     True
# D    False
# E    False
# dtype: bool

# %%
# s2의 값이 10보다 작은지 비교하세요.
# Out:
# A    False
# B    False
# C     True
# D    False
# E    False
# dtype: bool

# %%
# s1과 s2의 차를 출력하고 양수인지 비교하세요.
# Out:
# A     1.0
# B    -8.0
# C    37.0
# D   -26.0
# E   -35.0
# dtype: float64
# A     True
# B    False
# C     True
# D    False
# E    False
# dtype: bool

# %%
# s2가 짝수인지 비교하세요.
# Out:
# A     True
# B     True
# C    False
# D     True
# E     True
# dtype: bool

# %%
# s1이 홀수이면서 3의 배수인지 비교하세요.
# Out:
# A    False
# B    False
# C    False
# D    False
# E     True
# dtype: bool

# %%
# s1의 index의 값이 'A'인지 비교하세요.
# Out:
# array([ True, False, False, False, False])

# %% [markdown]
# ### DataFrame 생성 및 값 조회

# %% [markdown]
# #### 예시
# ![image.png](data:image/png;base64,...)

# %%
# 위 예시와 동일한 DataFrame을 리스트를 이용하여 생성하고 df에 저장하세요.
data =
df =
df
# Out:
#   요일   메뉴    가격
# 0  월  돈까스  9000
# 1  화  비빕밥  7500
# 2  수   냉면  8000
# 3  목   피자  9900
# 4  금  짜장면  7000

# %%
# 위 예시와 동일한 DataFrame을 Dictionary를 이용하여 생성하고 df에 저장하세요.
data =
df =
df
# Out:
#   요일   메뉴    가격
# 0  월  돈까스  9000
# 1  화  비빕밤  7500
# 2  수   냉면  8000
# 3  목   피자  9900
# 4  금  짜장면  7000

# %%
# df의 열 이름을 요일->Dayofweek, 메뉴->Menu, 가격->Price으로 변경하세요.
# Out:
#   Dayofweek Menu  Price
# 0         월  돈까스   9000
# 1         화  비빕밤   7500
# 2         수   냉면   8000
# 3         목   피자   9900
# 4         금  짜장면   7000

# %%
# df의 열 이름 중 Dayofweek를 Dow로 변경하세요.
# Out:
#   Dow Menu  Price
# 0   월  돈까스   9000
# 1   화  비빕밤   7500
# 2   수   냉면   8000
# 3   목   피자   9900
# 4   금  짜장면   7000

# %%
# df의 Dow 열을 추출하세요. (출력 형태 시리즈)
# Out:
# 0    월
# 1    화
# 2    수
# 3    목
# 4    금
# Name: Dow, dtype: object

# %%
# df의 마지막 열을 추출하세요.
# Out:
# 0    9000
# 1    7500
# 2    8000
# 3    9900
# 4    7000
# Name: Price, dtype: int64

# %%
# Dow 열을 추출하세요. (출력 형태 데이터프레임)
# Out:
#   Dow
# 0   월
# 1   화
# 2   수
# 3   목
# 4   금

# %%
# 1~2번 행을 추출하세요.
# Out:
#   Dow Menu  Price
# 1   화  비빕밤   7500
# 2   수   냉면   8000

# %%
# 월요일의 점심 메뉴를 출력하세요.
# Out:
# '돈까스'

# %%
# 사실 월요일 점심 메뉴는 돈까스가 아니었습니다.
# 월요일의 점셈 메뉴를 물로 변경하세요.
# Out:
# C:\Users\Mana\AppData\Local\Temp\ipykernel_61700\1780198979.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Menu'][0] = '물'
# ...

# %%
# 월요일의 음식 가격에서 7000을 빼세요
# Out:
# C:\Users\Mana\AppData\Local\Temp\ipykernel_61700\2281841871.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price'][0] -= 7000
#   Dow Menu  Price
# 0   월    물   2000
# 1   화  비빕밤   7500
# 2   수   냉면   8000
# 3   목   피자   9900
# 4   금  짜장면   7000

# %%
# 새 열 '비고'를 추가하고 값을 모두 '점심'으로 설정하세요.
# Out:
#   Dow Menu  Price  비고
# 0   월    물   2000  점심
# 1   화  비빕밤   7500  점심
# 2   수   냉면   8000  점심
# 3   목   피자   9900  점심
# 4   금  짜장면   7000  점심

# %% [markdown]
# ### DataFrame 속성 조회

# %%
# df의 차원 크기(rank)를 조회하세요.
# Out:
# 2

# %%
# df의 shape을 조회하세요.
# Out:
# (5, 4)

# %%
# df의 index를 조회하세요.
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# df의 columns를 조회하세요.
# Out:
# Index(['Dow', 'Menu', 'Price', '비고'], dtype='object')

# %%
# df의 values를 조회하세요.
# Out:
# array([['월', '물', 2000, '점심'],
#        ['화', '비빕밤', 7500, '점심'],
#        ['수', '냉면', 8000, '점심'],
#        ['목', '피자', 9900, '점심'],
#        ['금', '짜장면', 7000, '점심']], dtype=object)

# %%
# df의 열 별 데이터 타입을 조회하세요.
# Out:
# Dow      object
# Menu     object
# Price     int64
# 비고       object
# dtype: object

# %%
# df를 전치하세요.
# Out:
#           0     1     2     3     4
# Dow       월     화     수     목     금
# Menu      물   비빕밤    냉면    피자   짜장면
# Price  2000  7500  8000  9900  7000
# 비고       점심    점심    점심    점심    점심

# %% [markdown]
# #### DataFrame 연산

# %%
# df의 Price 열은 원 단위입니다. Price열의 값을 1000으로 나눈 값으로 천원 단위 열인 Price(천원)을 생성하세요.
# Out:
#   Dow Menu  Price  비고  Price(천원)
# 0   월    물   2000  점심        2.0
# 1   화  비빕밤   7500  점심        7.5
# 2   수   냉면   8000  점심        8.0
# 3   목   피자   9900  점심        9.9
# 4   금  짜장면   7000  점심        7.0

# %%
# df의 2번 행을 선택하세요.
# hint. 전치 + 열 선택
# Out:
# Dow             수
# Menu           냉면
# Price        8000
# 비고             점심
# Price(천원)     8.0
# Name: 2, dtype: object

# %%
# df의 Dow~Price 열을 선택하세요.
# hint. 팬시 혹은 전치+슬라이싱
# Out:
#   Menu Price
# 0    물  2000
# 1  비빕밤  7500
# 2   냉면  8000
# 3   피자  9900
# 4  짜장면  7000

# %%
# df에 새 열 "인원"을 추가합니다.
# 인원은 위에서부터 순서대로 [1, 2, 2, 4, 3] 명을 입력하시면 됩니다.
# Out:
#   Dow Menu  Price  비고  Price(천원)  인원
# 0   월    물   2000  점심        2.0   1
# 1   화  비빕밤   7500  점심        7.5   2
# 2   수   냉면   8000  점심        8.0   2
# 3   목   피자   9900  점심        9.9   4
# 4   금  짜장면   7000  점심        7.0   3

# %%
# df에 새 열 "총합"을 추가합니다.
# 총합은 Price * 인원입니다.
# Out:
#   Dow Menu  Price  비고  Price(천원)  인원     총합
# 0   월    물   2000  점심        2.0   1   2000
# 1   화  비빕밤   7500  점심        7.5   2  15000
# 2   수   냉면   8000  점심        8.0   2  16000
# 3   목   피자   9900  점심        9.9   4  39600
# 4   금  짜장면   7000  점심        7.0   3  21000

# %%
# df에 새 열 "총합(만원)"을 추가합니다.
# Out:
#   Dow Menu  Price  비고  Price(천원)  인원     총합  총합(만원)
# 0   월    물   2000  점심        2.0   1   2000    0.20
# 1   화  비빕밤   7500  점심        7.5   2  15000    1.50
# 2   수   냉면   8000  점심        8.0   2  16000    1.60
# 3   목   피자   9900  점심        9.9   4  39600    3.96
# 4   금  짜장면   7000  점심        7.0   3  21000    2.10

# %%
# df의 Price 값이 7000원 이상이면서 총합이 20000원 이상인지 확인하세요.
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# dtype: bool
